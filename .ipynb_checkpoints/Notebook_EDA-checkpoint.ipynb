# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_brut = pd.read_csv ('dataimoreg.csv')

# %%
df_brut
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# 0               473.0      1397.0       417.0         1.4817
# 1               349.0       862.0       340.0         6.9133
# 2               214.0       931.0       214.0         1.5536
# 3               229.0       597.0       227.0         1.5284
# 4               373.0      1130.0       372.0         4.0815
# ...               ...         ...         ...            ...
# 16507           278.0       745.0       250.0         3.0625
# 16508           504.0      1131.0       458.0         2.6133
# 16509           461.0      1206.0       429.0         4.4958
# 16510           840.0      2546.0       773.0         2.5750
# 16511           462.0      1259.0       420.0         2.2478
#
#        median_house_value ocean_proximity
# 0                 72000.0          INLAND
# 1                274100.0       <1H OCEAN
# 2                 58300.0          INLAND
# 3                200000.0       <1H OCEAN
# 4                117900.0          INLAND
# ...                   ...             ...
# 16507             93800.0          INLAND
# 16508            103100.0        NEAR BAY
# 16509            192600.0          INLAND
# 16510            153500.0       <1H OCEAN
# 16511             81100.0      NEAR OCEAN
#
# [16512 rows x 11 columns]

# %% [markdown]
# # EDA 12/01

# %% [markdown]
# ## quick view

# %%
#first quick view 
df_brut.describe()
# Out:
#          Unnamed: 0     longitude      latitude  housing_median_age  \
# count  16512.000000  16512.000000  16512.000000        16512.000000
# mean   10295.498789   -119.564046     35.626523           28.624516
# std     5941.973488      2.005033      2.139150           12.597980
# min        0.000000   -124.350000     32.540000            1.000000
# 25%     5178.750000   -121.790000     33.930000           18.000000
# 50%    10263.500000   -118.490000     34.250000           29.000000
# 75%    15438.250000   -118.010000     37.710000           37.000000
# max    20639.000000   -114.310000     41.950000           52.000000
#
#         total_rooms  total_bedrooms    population    households  \
# count  16512.000000    16336.000000  16512.000000  16512.000000
# mean    2644.170603      539.319540   1435.017260    501.135962
# std     2213.946369      425.207704   1158.151967    385.650673
# min        6.000000        2.000000      3.000000      2.000000
# 25%     1446.000000      296.000000    788.000000    280.000000
# 50%     2116.000000      435.000000   1168.000000    410.000000
# 75%     3154.000000      647.000000   1738.000000    606.000000
# max    39320.000000     6445.000000  35682.000000   6082.000000
#
#        median_income  median_house_value
# count   16512.000000        16512.000000
# mean        3.864091       206509.251453
# std         1.893244       115225.957661
# min         0.499900        14999.000000
# 25%         2.562500       119400.000000
# 50%         3.531300       179300.000000
# 75%         4.733225       264500.000000
# max        15.000100       500001.000000

# %%
#first quick view for types
df_brut.dtypes
# Out:
# Unnamed: 0              int64
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
df_brut = df_brut.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ## missing data

# %%
#missing data
df_brut.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        176
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
#Inputation of missing value by the median 
median = df_brut["total_bedrooms"].median()
df_brut['total_bedrooms'].fillna(median, inplace=True)

# %%
df_brut.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# ## Working on duplicate

# %%
# df_brut.nunique()

# %%
#New col long and lat to see unique place
# cols = ["longitude","latitude"]
# df_brut["longitude,latitude"] = df_brut[cols].apply(lambda row: ' ; '.join(row.values.astype(str)), axis=1)

# %% [markdown]
# ### def fonction to put numerical value in ocean proximity

# %%
# def ocean_proximity_to_num (row):
#     if row["ocean_proximity"] == '<1H OCEAN' :
#         return 0
#     if row["ocean_proximity"] == 'INLAND' :
#         return 1
#     if row["ocean_proximity"] == 'NEAR OCEAN' :
#         return 2
#     if row["ocean_proximity"] == 'NEAR BAY' :
#         return 3
#     if row["ocean_proximity"] == 'ISLAND' :
#         return 4
#     return "NaN"

# %%
# def num_to_ocean_proximity (row):
#     if row["num_ocean_proximity"] == 0 :
#         return '<1H OCEAN'
#     if row["num_ocean_proximity"] == 1 :
#         return 'INLAND'
#     if row["num_ocean_proximity"] == 2 :
#         return 'NEAR OCEAN'
#     if row["num_ocean_proximity"] == 3 :
#         return 'NEAR BAY'
#     if row["num_ocean_proximity"] == 4 :
#         return 'ISLAND'
#     return "NaN"

# %%
# df_brut["num_ocean_proximity"] = df_brut.apply (lambda row: ocean_proximity_to_num(row),axis=1)

# %%
# #checking 
# df_brut["ocean_proximity"].value_counts()

# %%
# df_brut["num_ocean_proximity"].value_counts()

# %%
# df_duplicate = df_brut[df_brut["longitude,latitude"].duplicated(keep=False)]

# %%
# df_duplicate.sort_values("longitude,latitude")

# %%
# df_test = df_duplicate.groupby(['longitude,latitude']).mean().reset_index()

# %%
# #Drop not usefull column and have back ocean proximity
# df_clean = df_brut.groupby(['longitude,latitude']).mean().reset_index()

# #df_clean = df_clean.drop(columns=['Unnamed: 0',"longitude","latitude"])
# df_clean["ocean_proximity"] = df_clean.apply (lambda row: num_to_ocean_proximity(row),axis=1)

# %%
# df_clean['longitude,latitude'].nunique()

# %% [markdown]
# ## dataframe cleaned 12/01 , checking outliers

# %%
#Dataframe i use for model
df_clean = df_brut.copy()

# %%
columns_numerical = df_clean.columns[1:8]
columns_numerical
# Out:
# Index(['latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms',
#        'population', 'households', 'median_income'],
#       dtype='object')

# %%
df_clean.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  16512.000000  16512.000000        16512.000000  16512.000000
# mean    -119.564046     35.626523           28.624516   2644.170603
# std        2.005033      2.139150           12.597980   2213.946369
# min     -124.350000     32.540000            1.000000      6.000000
# 25%     -121.790000     33.930000           18.000000   1446.000000
# 50%     -118.490000     34.250000           29.000000   2116.000000
# 75%     -118.010000     37.710000           37.000000   3154.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    16512.000000  16512.000000  16512.000000   16512.000000
# mean       538.207607   1435.017260    501.135962       3.864091
# std        423.071026   1158.151967    385.650673       1.893244
# min          2.000000      3.000000      2.000000       0.499900
# 25%        297.000000    788.000000    280.000000       2.562500
# 50%        435.000000   1168.000000    410.000000       3.531300
# 75%        644.000000   1738.000000    606.000000       4.733225
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        16512.000000
# mean        206509.251453
# std         115225.957661
# min          14999.000000
# 25%         119400.000000
# 50%         179300.000000
# 75%         264500.000000
# max         500001.000000

# %%
df_clean.sort_values("population").tail(40)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 
# 13186     11973.0      3933.0         3.3086            138100.0
# 1749      12153.0      4372.0         3.2652            152800.0
# 10059     12203.0      3701.0         8.4045            451100.0
# 5676      12427.0      2826.0         2.7377             28300.0
# 13564     12873.0      3931.0         8.0137            399200.0
# 8684      13251.0      4339.0         4.5841            212300.0
# 12510     15037.0      4072.0         6.6288            339700.0
# 13152     15507.0      5050.0         6.0191            253900.0
# 13922     16122.0      5189.0         7.4947            366300.0
# 4185      16305.0      5358.0         4.9516            153700.0
# 14503     28566.0      6082.0         2.3087            118800.0
# 7471      35682.0      4769.0         2.5729            134400.0
#
#       ocean_proximity
# 14878          INLAND
# 9485           INLAND
# 10301       <1H OCEAN
# 14136       <1H OCEAN
# 14204       <1H OCEAN
# 15745       <1H OCEAN
# 11707       <1H OCEAN
# 12726       <1H OCEAN
# 13049       <1H OCEAN
# 10398       <1H OCEAN
# 8988           INLAND
# 6419           INLAND
# 7079        <1H OCEAN
# 1115        <1H OCEAN
# 9966           INLAND
# 9641        <1H OCEAN
# 4078           INLAND
# 7039       NEAR OCEAN
# 29             INLAND
# 14896       <1H OCEAN
# 5121           INLAND
# 2704           INLAND
# 4737        <1H OCEAN
# 10716       <1H OCEAN
# 720            INLAND
# 7007        <1H OCEAN
# 5073           INLAND
# 2131        <1H OCEAN
# 13186          INLAND
# 1749        <1H OCEAN
# 10059       <1H OCEAN
# 5676       NEAR OCEAN
# 13564      NEAR OCEAN
# 8684        <1H OCEAN
# 12510       <1H OCEAN
# 13152       <1H OCEAN
# 13922       <1H OCEAN
# 4185           INLAND
# 14503       <1H OCEAN
# 7471        <1H OCEAN

# %% [markdown]
# ###  plot outliers with boxplot

# %%
#We see that from all outlier 2 point look really far bigger than other 
for i in columns_numerical :
    
    fig, ax = plt.subplots()
    ax.boxplot(df_clean[i], vert=0)
    plt.title(label=i)
   
    plt.show()

# %%
#Let's see what those point are 
fig, ax = plt.subplots()
ax.boxplot(df_clean["population"], vert=0)
plt.title(label="population")
# Out:
# Text(0.5, 1.0, 'population')

# %%
#The 2 location wich are real heavy outlier
df_clean[df_clean["population"] > 20000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7471     -117.42     33.35                14.0      25135.0          4819.0
# 14503    -121.79     36.64                11.0      32627.0          6445.0
#
#        population  households  median_income  median_house_value  \
# 7471      35682.0      4769.0         2.5729            134400.0
# 14503     28566.0      6082.0         2.3087            118800.0
#
#       ocean_proximity
# 7471        <1H OCEAN
# 14503       <1H OCEAN

# %%
# both this location are military infrastructure , so it's not somthing relevent for house price , we can remove them

from IPython import display
display.Image("https://user-images.githubusercontent.com/104862908/212533897-cfaeeda6-9f09-48aa-a47f-7a6f40cb8dc7.PNG")

# %%
#Remove the 2 line 
df_clean = df_clean[df_clean["population"] < 20000]

# %%
#it improved a lot the boxplot , we will check later if we can improve it more 
fig, ax = plt.subplots()
ax.boxplot(df_clean["population"], vert=0)
plt.title(label="population")
# Out:
# Text(0.5, 1.0, 'population')

# %%
df_clean.housing_median_age.describe()
# Out:
# count    16510.000000
# mean        28.626469
# std         12.597482
# min          1.000000
# 25%         18.000000
# 50%         29.000000
# 75%         37.000000
# max         52.000000
# Name: housing_median_age, dtype: float64

# %%
columns_numerical
# Out:
# Index(['latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms',
#        'population', 'households', 'median_income'],
#       dtype='object')

# %%
df_clean_bins = df_clean

# %%
#We are looking for visually how bins of each features impatch the target 
for i in columns_numerical :
    name_col = "bins_" + i
    df_clean_bins[name_col] = pd.cut(df_clean_bins[i] , 7)
    plt.figure(figsize = (16,8))
    sns.boxplot(x = df_clean_bins[name_col] , y = df_clean_bins.median_house_value)
    plt.show()

# %% [markdown]
# # Write df clean

# %%
df_clean
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.84     36.77                 6.0       1853.0           473.0
# 1        -117.80     33.68                 8.0       2032.0           349.0
# 2        -120.19     36.60                25.0        875.0           214.0
# 3        -118.32     34.10                31.0        622.0           229.0
# 4        -121.23     37.79                21.0       1922.0           373.0
# ...          ...       ...                 ...          ...             ...
# 16507    -121.90     39.59                20.0       1465.0           278.0
# 16508    -122.25     38.11                49.0       2365.0           504.0
# 16509    -121.22     38.92                19.0       2531.0           461.0
# 16510    -118.14     34.16                39.0       2776.0           840.0
# 16511    -124.13     40.80                31.0       2152.0           462.0
#
#        population  households  median_income  median_house_value  \
# 0          1397.0       417.0         1.4817             72000.0
# 1           862.0       340.0         6.9133            274100.0
# 2           931.0       214.0         1.5536             58300.0
# 3           597.0       227.0         1.5284            200000.0
# 4          1130.0       372.0         4.0815            117900.0
# ...           ...         ...            ...                 ...
# 16507       745.0       250.0         3.0625             93800.0
# 16508      1131.0       458.0         2.6133            103100.0
# 16509      1206.0       429.0         4.4958            192600.0
# 16510      2546.0       773.0         2.5750            153500.0
# 16511      1259.0       420.0         2.2478             81100.0
#
#       ocean_proximity     bins_latitude bins_housing_median_age  \
# 0              INLAND  (36.573, 37.917]          (0.949, 8.286]
# 1           <1H OCEAN  (32.531, 33.884]          (0.949, 8.286]
# 2              INLAND  (36.573, 37.917]        (22.857, 30.143]
# 3           <1H OCEAN  (33.884, 35.229]        (30.143, 37.429]
# 4              INLAND  (36.573, 37.917]        (15.571, 22.857]
# ...               ...               ...                     ...
# 16507          INLAND  (39.261, 40.606]        (15.571, 22.857]
# 16508        NEAR BAY  (37.917, 39.261]          (44.714, 52.0]
# 16509          INLAND  (37.917, 39.261]        (15.571, 22.857]
# 16510       <1H OCEAN  (33.884, 35.229]        (37.429, 44.714]
# 16511      NEAR OCEAN   (40.606, 41.95]        (30.143, 37.429]
#
#           bins_total_rooms bins_total_bedrooms       bins_population  \
# 0      (-33.314, 5622.286]   (-4.208, 888.857]   (-13.302, 2331.857]
# 1      (-33.314, 5622.286]   (-4.208, 888.857]   (-13.302, 2331.857]
# 2      (-33.314, 5622.286]   (-4.208, 888.857]   (-13.302, 2331.857]
# 3      (-33.314, 5622.286]   (-4.208, 888.857]   (-13.302, 2331.857]
# 4      (-33.314, 5622.286]   (-4.208, 888.857]   (-13.302, 2331.857]
# ...                    ...                 ...                   ...
# 16507  (-33.314, 5622.286]   (-4.208, 888.857]   (-13.302, 2331.857]
# 16508  (-33.314, 5622.286]   (-4.208, 888.857]   (-13.302, 2331.857]
# 16509  (-33.314, 5622.286]   (-4.208, 888.857]   (-13.302, 2331.857]
# 16510  (-33.314, 5622.286]   (-4.208, 888.857]  (2331.857, 4660.714]
# 16511  (-33.314, 5622.286]   (-4.208, 888.857]   (-13.302, 2331.857]
#
#            bins_households bins_median_income
# 0        (-3.356, 767.143]     (0.485, 2.571]
# 1        (-3.356, 767.143]     (6.714, 8.786]
# 2        (-3.356, 767.143]     (0.485, 2.571]
# 3        (-3.356, 767.143]     (0.485, 2.571]
# 4        (-3.356, 767.143]     (2.571, 4.643]
# ...                    ...                ...
# 16507    (-3.356, 767.143]     (2.571, 4.643]
# 16508    (-3.356, 767.143]     (2.571, 4.643]
# 16509    (-3.356, 767.143]     (2.571, 4.643]
# 16510  (767.143, 1532.286]     (2.571, 4.643]
# 16511    (-3.356, 767.143]     (0.485, 2.571]
#
# [16510 rows x 17 columns]

# %%
df_clean.to_csv(r'dataframeclean.csv', index=False, header=True)
